# %% [markdown]
# # Case 6 Data generation
#
# This case corresponds to:
#
# * Each series is generated using the GRATIS method and adjusting for the count data nature.
# * All series are generated aiming for the same features and are dependent
# * Each series has a lenght of 200 time steps
# * There's a total of 100 parallel time series
#
# The data simulated in R is processed in this notebook. The code for the simulation can be found in "simulation.R" in this folder.

# %%
import os
import sys 
import numpy as np 
import pandas as pd

src_path = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.append(src_path)

from DataSimulation.utils import plot_simulations, process_simulated_data

# %%
sim_data = pd.read_csv("monthly_sim_100.csv")
sim_data.head()
# Out:
#    Unnamed: 0  Series 1  Series 2  Series 3  Series 4  Series 5  Series 6  \
# 0           1  4.185100  5.606343  0.140543 -0.252367 -1.849349 -1.793306
# 1           2  0.921781  1.305166  1.059336 -1.528730 -7.447748 -4.312123
# 2           3 -1.984904  2.049704 -1.315709 -1.886878 -3.276752 -3.066237
# 3           4  2.236248 -1.659972 -1.685345 -2.944067 -7.269260 -4.925833
# 4           5  4.616113  3.002367  0.594622  1.004346 -7.651441 -0.820380
#
#    Series 7  Series 8  Series 9  ...  Series 91  Series 92  Series 93  \
# 0 -0.704236 -3.837174 -3.265439  ...  -4.079917  -0.820107  -3.398308
# 1 -1.537217  0.761894 -1.318418  ...   0.125186  -3.001073  -4.684891
# 2 -1.742020 -7.094344  1.970896  ...   0.639812 -10.796825  -7.042460
# 3  0.885537 -7.449778 -2.020885  ...   2.971881  -4.635850 -13.501150
# 4 -2.237234  0.514350  1.622437  ...   0.148007   1.050074  -5.806897
#
#    Series 94  Series 95  Series 96  Series 97  Series 98  Series 99  \
# 0  -3.715872   1.678257   4.204703  -0.137012   0.914409   2.060316
# 1  -8.449037   1.792886   6.355469  -3.510159  -0.600832  -1.729660
# 2  -8.853966  -0.059075  -0.786430  -0.478226   0.050994  -3.294785
# 3  -3.038801  -1.745478   3.215044  -2.215241  -1.251735  -8.145182
# 4  -7.579693  -2.028936   0.051299   8.326589   0.944347  -5.160762
#
#    Series 100
# 0    4.039311
# 1   -0.338110
# 2    0.587925
# 3    0.794738
# 4   -0.982753
#
# [5 rows x 101 columns]

# %%
s_data = sim_data.iloc[:, 1:].to_numpy()
s_data.shape
# Out:
# (220, 100)

# %%
data = s_data[20:, :]
data = process_simulated_data(data, 1)

# %%
plot_simulations(data, 2)

# %%
data.shape
# Out:
# (200, 100)

# %%
np.savetxt("data.csv", data, delimiter=",")
