# %% [markdown]
# # Case 7 Data generation
#
# This case corresponds to:
#
# * Each series is generated using the GRATIS method and adjusting for the count data nature.
# * All series are generated aiming for the same features and are dependent
# * Each series has a lenght of 1000 time steps
# * There's a total of 10 parallel time series
#
# The data simulated in R is processed in this notebook. The code for the simulation can be found in "simulation.R" in this folder.

# %%
import os
import sys 
import numpy as np 
import pandas as pd

src_path = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.append(src_path)

from DataSimulation.utils import plot_simulations, process_simulated_data

# %%
sim_data = pd.read_csv("hourly_sim_10.csv")
sim_data.head()
# Out:
#    Unnamed: 0  Series 1  Series 2  Series 3  Series 4  Series 5  Series 6  \
# 0           1  1.625237 -6.434164 -1.740672  4.828205  3.581116 -5.247138
# 1           2  2.678984 -5.136745 -4.281274  2.016490  3.213042 -3.550901
# 2           3 -1.278267 -6.411370 -4.682464  2.480945  2.228321 -1.901244
# 3           4  0.048971 -4.193643 -1.494942 -0.428102  1.064832 -6.156185
# 4           5  3.799635 -4.274869  0.204968 -1.254504  1.435471 -3.901267
#
#    Series 7  Series 8  Series 9  Series 10
# 0  0.658613  0.148919  1.693044  -0.954876
# 1  2.346009 -5.468079  0.459345  -0.965159
# 2  1.453739 -1.967583  1.989905   1.719495
# 3  1.428355 -3.701427  3.665268  -4.471981
# 4  2.088131 -3.781795  6.740663   8.178970

# %%
s_data = sim_data.iloc[:, 1:].to_numpy()
s_data.shape
# Out:
# (1100, 10)

# %%
data = s_data[100:, :]
data = process_simulated_data(data, 1)

# %%
plot_simulations(data, 2)

# %%
data.shape
# Out:
# (1000, 10)

# %%
np.savetxt("data.csv", data, delimiter=",")
